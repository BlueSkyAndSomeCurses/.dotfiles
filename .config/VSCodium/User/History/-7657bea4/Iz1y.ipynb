# %%
import pandas as pd

# %%
df = pd.read_csv("census.csv")
df
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
# 0         40       3         6      1       0  Alabama            Alabama
# 1         50       3         6      1       1  Alabama     Autauga County
# 2         50       3         6      1       3  Alabama     Baldwin County
# 3         50       3         6      1       5  Alabama     Barbour County
# 4         50       3         6      1       7  Alabama        Bibb County
# ...      ...     ...       ...    ...     ...      ...                ...
# 3188      50       4         8     56      37  Wyoming  Sweetwater County
# 3189      50       4         8     56      39  Wyoming       Teton County
# 3190      50       4         8     56      41  Wyoming       Uinta County
# 3191      50       4         8     56      43  Wyoming    Washakie County
# 3192      50       4         8     56      45  Wyoming      Weston County
#
#       CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  \
# ...

# %%
df.groupby("STNAME").CTYNAME.count().idxmax()
# Out:
# 'Texas'

# %%
df
max_people = df.loc[:,["POPESTIMATE2010","POPESTIMATE2011", "POPESTIMATE2012","POPESTIMATE2013", "POPESTIMATE2014","POPESTIMATE2015"]].max(axis="columns")

min_people = df.loc[:,["POPESTIMATE2010","POPESTIMATE2011", "POPESTIMATE2012","POPESTIMATE2013", "POPESTIMATE2014","POPESTIMATE2015"]].min(axis="columns")

df.iloc[pd.Series.abs(max_people - min_people).idxmax()].CTYNAME
# Out:
# 'Texas'

# %%
tmp_f = df[df["REGION"].isin([1,2])]
tmp_f = tmp_f.loc[tmp_f["CTYNAME"].str.contains("Washington")]
tmp_f
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY        STNAME  \
# 703       50       2         3     17     189      Illinois
# 799       50       2         3     18     175       Indiana
# 896       50       2         4     19     183          Iowa
# 1005      50       2         4     20     201        Kansas
# 1211      50       1         1     23      29         Maine
# 1419      50       2         4     27     163     Minnesota
# 1618      50       2         4     29     221      Missouri
# 1770      50       2         4     31     177      Nebraska
# 1918      50       1         2     36     115      New York
# 2162      50       2         3     39     167          Ohio
# 2345      50       1         2     42     125  Pennsylvania
# 2355      50       1         1     44       9  Rhode Island
# 2863      50       1         1     50      23       Vermont
# 3163      50       2         3     55     131     Wisconsin
#
# ...
